# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.random.randint(0, 100, 350)
b = np.random.randint(0, 100, 350)

# %%
a
# Out:
# array([34, 67, 74,  9, 10, 47, 10, 63, 97, 52, 42, 88, 44, 92, 45, 67, 98,
#        56, 52, 31, 98, 28, 55, 65, 44, 24, 15, 65, 77, 62, 49,  8, 80, 90,
#        81, 50, 73, 81, 57, 28, 17,  0, 91, 97, 74, 27, 27, 29, 44, 58,  1,
#        91, 54,  2, 11, 69, 25,  8, 84, 41, 83, 51,  9, 59, 80, 70, 71, 57,
#        71, 68,  8, 21, 93, 28,  0, 79, 93, 34, 60, 31, 90, 22, 67, 74, 93,
#        30, 41, 47, 46, 57, 61,  7,  6, 45, 71, 89, 52, 46, 42, 72, 23, 41,
#        92, 79, 94, 28, 43, 57, 57, 76, 75, 69, 13, 27, 64, 62, 88, 42, 31,
#        75, 67, 24, 28, 17, 81,  1, 85, 19, 59, 49, 53, 46, 91, 75, 78, 85,
#        29, 61, 63,  9, 75, 82, 63, 16, 98, 12, 81, 72,  9, 94, 54, 73, 42,
#        85, 21, 59, 41, 18, 60, 89, 71, 48, 90, 48, 81,  0, 25, 77, 39, 11,
#         3, 96, 94, 44, 66, 34, 40, 51, 78, 32,  0, 70, 49, 87, 49, 58, 55,
#        54, 84, 84, 80, 83, 94, 40, 95, 97, 25,  9, 36, 76, 69, 68, 96, 47,
# ...

# %%
b
# Out:
# array([44, 17, 90, 49, 11, 50, 22,  0,  2, 64, 57, 84, 36, 12, 51, 60,  1,
#        81, 23, 93, 40, 69, 25, 11, 52, 94, 14, 81, 17, 75, 25, 17, 49, 44,
#        74, 45, 43, 16,  8, 27, 83, 18, 51, 59, 11, 56, 33, 90, 88, 33, 33,
#        31,  9, 29, 50, 28, 52, 22, 83, 44, 47, 22, 30, 42,  7, 47,  6, 50,
#        84, 98, 10,  7, 61, 54, 42, 28, 80, 14, 82, 89, 57, 88, 38, 70, 17,
#        94, 51, 56, 16, 68, 13, 97, 37, 94, 74, 43, 55, 98, 29, 74, 23, 47,
#        46, 49, 72,  0, 15, 34, 33,  7, 10, 42, 77, 83, 49, 54, 74, 75, 81,
#        84, 57, 29, 56, 31, 73, 36, 18, 33, 28, 97, 83, 19, 53, 53, 89, 60,
#        67, 34,  9, 28, 65,  2, 14, 46, 20, 25, 27,  5, 90, 71, 80, 95, 49,
#        21, 98, 32, 37,  6,  4,  5, 32, 34, 58, 67, 21, 95, 14, 78, 75, 64,
#         9, 51, 91, 72, 66, 11,  5, 38, 60,  3,  3, 65, 14, 86, 27, 57, 58,
#        82, 69, 92,  6, 82, 36, 92, 16, 79, 64, 81, 78, 70, 57, 21, 44, 63,
# ...

# %%
df = pd.DataFrame({'a':a, 'b':b})

# %%
df
# Out:
#       a   b
# 0    34  44
# 1    67  17
# 2    74  90
# 3     9  49
# 4    10  11
# ..   ..  ..
# 345  23   7
# 346  15  65
# 347  35  31
# 348  89   8
# 349  56  94
#
# [350 rows x 2 columns]

# %%
sns.histplot(x=a, data=df, bins=20)
plt.show()

# %%
sns.histplot(x=b, data=df, bins=20)
plt.show()

# %%
sns.swarmplot(y=a, data=df)
# Out:
# <AxesSubplot:>

# %%
sns.swarmplot(y=b, data=df)
# Out:
# <AxesSubplot:>
